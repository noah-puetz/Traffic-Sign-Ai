# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow as tf
import cv2
from PIL import Image

# %%
height = 30
width = 30
channels = 3

model = keras.models.load_model("Traffic_Sign_Net")

# %%
y_test=pd.read_csv(r'C:\Users\z0045vws\Desktop\TH_Koeln_Projekt_Adversarial_Attack\Test.csv')
labels=y_test['Path'].to_numpy()
y_test=y_test['ClassId'].values
data=[]

# %%
for f in labels:
    image=cv2.imread(r'C:\Users\z0045vws\Desktop\TH_Koeln_Projekt_Adversarial_Attack\Test/'+f.replace('Test', ''))
    image_from_array = Image.fromarray(image, 'RGB')
    size_image = image_from_array.resize((height, width))
    data.append(np.array(size_image))

# %%
X_test=np.array(data)
X_test = X_test.astype('float32')/255

pred = model.predict(X_test)

# %%
labels = ["20 km/h","30 km/h","50 km/h","60 km/h","70 km/h","80 km/h","80 km/h Aufhebung","100 km/h",
          "120 km/h", "Überholverbot", "LKW-Überholverbot", "Vorfahrt", "Vorfahrtsstraße","Vorfahrt gewähren", 
          "Stop","Fahrverbot","Verbot für Lastwagen","Einfahrt verboten","Gefahr","Linkskurve","Rechtskurve","Doppelkurve",
          "Bodenwelle","Schleudergefahr","Verengung","Baustelle","Ampel","Zebrastreifen","Kinder","Fahrradweg","Schneegefahr",
          "Wildwechsel","Unbegrenzte Geschwindigkeit","Rechtsabbiegen", "Linksabbiegen", "Geradeaus fahren", "Geradeaus oder Rechtsabbiegen",
          "Geradeaus oder Linksabbiegen", "Hindernis rechts umfahren", " Hindernis links umfahren", "Kreisverkehr", "Ende des Überholverbotes",
          "Ende des LKW-Überholverbotes"]

# %%
for d in range(100, 200):
    i = d
    plt.imshow(X_test[i])
    plt.show()
    x = np.argmax(pred[i])
    print(labels[x])
    print("Confidence",pred[i][x])
# Out:
# 30 km/h
# Confidence 1.0
# LKW-Überholverbot
# Confidence 1.0
# 80 km/h
# Confidence 0.99986935
# Vorfahrt
# Confidence 1.0
# Rechtsabbiegen
# Confidence 1.0
# 70 km/h
# Confidence 1.0
# Geradeaus fahren
# Confidence 1.0
# Baustelle
# Confidence 1.0
# Rechtsabbiegen
# Confidence 1.0
# 70 km/h
# Confidence 1.0
# 30 km/h
# Confidence 1.0
# Stop
# Confidence 1.0
# Verbot für Lastwagen
# Confidence 1.0
# LKW-Überholverbot
# Confidence 1.0
# Kinder
# Confidence 0.5259862
# 60 km/h
# Confidence 1.0
# Zebrastreifen
# Confidence 0.99999917
# Fahrradweg
# Confidence 0.99998283
# 30 km/h
# Confidence 1.0
# Einfahrt verboten
# Confidence 1.0
# Vorfahrt gewähren
# Confidence 1.0
# 100 km/h
# Confidence 1.0
# 30 km/h
# Confidence 0.9999943
# 120 km/h
# Confidence 1.0
# 50 km/h
# Confidence 1.0
# LKW-Überholverbot
# Confidence 1.0
# LKW-Überholverbot
# Confidence 1.0
# Rechtskurve
# Confidence 0.6044038
# 30 km/h
# Confidence 1.0
# 80 km/h Aufhebung
# Confidence 0.99999774
# Geradeaus oder Rechtsabbiegen
# Confidence 1.0
# 60 km/h
# Confidence 0.9480934
# Stop
# Confidence 0.999998
# Vorfahrt gewähren
# Confidence 1.0
# Vorfahrt
# Confidence 1.0
# LKW-Überholverbot
# Confidence 1.0
# Gefahr
# Confidence 1.0
# Kreisverkehr
# Confidence 0.99999976
# 50 km/h
# Confidence 1.0
# Hindernis rechts umfahren
# Confidence 1.0
# Ende des Überholverbotes
# Confidence 1.0
# 70 km/h
# Confidence 1.0
# 80 km/h Aufhebung
# Confidence 1.0
# Gefahr
# Confidence 0.9999893
# Einfahrt verboten
# Confidence 1.0
# Baustelle
# Confidence 0.99812526
# 50 km/h
# Confidence 1.0
# Ende des Überholverbotes
# Confidence 0.99394965
# Vorfahrt
# Confidence 1.0
# Doppelkurve
# Confidence 1.0
# 100 km/h
# Confidence 1.0
# Verengung
# Confidence 0.9999943
# Vorfahrt
# Confidence 1.0
# Baustelle
# Confidence 1.0
# Einfahrt verboten
# Confidence 1.0
# 60 km/h
# Confidence 1.0
# 80 km/h Aufhebung
# Confidence 1.0
# Überholverbot
# Confidence 1.0
# 100 km/h
# Confidence 1.0
# 70 km/h
# Confidence 0.999972
# Vorfahrt gewähren
# Confidence 1.0
# Verbot für Lastwagen
# Confidence 1.0
# 70 km/h
# Confidence 1.0
# Baustelle
# Confidence 0.6007956
# Gefahr
# Confidence 0.9999989
# Überholverbot
# Confidence 1.0
# Vorfahrt gewähren
# Confidence 1.0
# Stop
# Confidence 1.0
# Fahrradweg
# Confidence 1.0
# Einfahrt verboten
# Confidence 1.0
# Vorfahrt gewähren
# Confidence 1.0
# Hindernis rechts umfahren
# Confidence 1.0
# Ampel
# Confidence 1.0
# Baustelle
# Confidence 1.0
# Rechtsabbiegen
# Confidence 1.0
# 30 km/h
# Confidence 0.999998
# 60 km/h
# Confidence 0.99595106
# Kreisverkehr
# Confidence 1.0
# Vorfahrt gewähren
# Confidence 1.0
# 50 km/h
# Confidence 1.0
# 120 km/h
# Confidence 1.0
# 70 km/h
# Confidence 1.0
# Geradeaus oder Rechtsabbiegen
# Confidence 1.0
# Baustelle
# Confidence 1.0
# Rechtskurve
# Confidence 1.0
# Baustelle
# Confidence 1.0
# Gefahr
# Confidence 1.0
# 30 km/h
# Confidence 1.0
# LKW-Überholverbot
# Confidence 1.0
# 120 km/h
# Confidence 0.9999981
# LKW-Überholverbot
# Confidence 0.9999999
# Fahrradweg
# Confidence 1.0
# Vorfahrtsstraße
# Confidence 1.0
# Hindernis rechts umfahren
# Confidence 1.0
# Wildwechsel
# Confidence 1.0
# 50 km/h
# Confidence 1.0
# 120 km/h
# Confidence 0.9840036
# Hindernis rechts umfahren
# Confidence 1.0
# 30 km/h
# Confidence 0.78743654
# Kinder
# Confidence 1.0
